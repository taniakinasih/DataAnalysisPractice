# %%
import pandas as pd
import parse_data as mm

# --- Pengaturan Tampilan Pandas ---
# Ini akan memastikan semua kolom ditampilkan dalam satu baris tabel
pd.set_option('display.max_columns', None) 
pd.set_option('display.width', 1000) 

# --- Eksekusi dan Pemrosesan ---
data_file = "Air_Quality_Data.csv"
df = mm.parse(data_file)

print (df)
# Out:
# Loading data dari: Air_Quality_Data.csv
# Menghapus 2067 baris
#        month  concentration  dew_point  temperature  pressure  wind_speed  rainfall_duration
# 24         1          129.0        -16         -4.0    1020.0        1.79                  0
# 25         1          148.0        -15         -4.0    1020.0        2.68                  0
# 26         1          159.0        -11         -5.0    1021.0        3.57                  0
# 27         1          181.0         -7         -5.0    1022.0        5.36                  0
# 28         1          138.0         -7         -5.0    1022.0        6.25                  0
# ...      ...            ...        ...          ...       ...         ...                ...
# 43819     12            8.0        -23         -2.0    1034.0      231.97                  0
# 43820     12           10.0        -22         -3.0    1034.0      237.78                  0
# ...

# %%
import pandas as pd
import descriptive as dam # Impor modul dengan alias dam

# 1. Definisikan nama file Anda
FILE_PATH = "Air_Quality_Data.csv"

# 2. Bersihkan dan Proses Data
df_clean = dam.parse_and_clean_data(FILE_PATH)

# 3. Tampilkan Statistik Deskriptif (seperti yang Anda inginkan)
if not df_clean.empty:
    # Fungsi ini secara otomatis mengecualikan 'month' dan menampilkan hasilnya
    dam.get_descriptive_stats(df_clean)
else:
    print("Tidak dapat menampilkan statistik karena DataFrame kosong.")
# Out:
# Memulai pembersihan data...
# Loading data dari: Air_Quality_Data.csv
# Menghapus 2067 baris
# Pembersihan selesai.
#
# --- Statistik Deskriptif ---
